# %% [markdown]
# ### Code for generating data and plotting all figures of the article:
#
# **A spectral viewpoint on the single defect tight-binding chain**
#
# by Sayan Roy

# %%
# Load IPython's autoreload extension
# %load_ext IPython.extensions.autoreload
# %autoreload 2

import build as figs
import numpy as np
# Out:
# The IPython.extensions.autoreload extension is already loaded. To reload it, use:
#   %reload_ext IPython.extensions.autoreload

# %% [markdown]
# ### Generating Data
#
# This notebook demonstrates how to load and plot the data used in the paper. All datasets corresponding to the published parameter values have **already been generated** and are available in the `Data/` directory (`Figure1.csv` … `Figure2.csv`). There is no need to regenerate data** to reproduce the figures of the article.
#
#
# #### Optional: Regenerating data
#
# If you wish to reproduce the datasets or extend the analysis to other parameter values, you may regenerate the data using the functions in `build.py`. For example:
#
# ```python
#
# # Example: regenerate data for specific figures (optional)
# from build import generate_figure1_csv
#
# generate_figure1_csv(out_csv="Data/Figure2a.csv", save=True)
# ```
#
# Note: To explore different parameter regimes, you can modify the parameters inside the functions in `build.py`. The default parameters reproduce the results in the paper.

# %% [markdown]
# ### Plotting Figures
#
# The following sections reproduce each figure from the paper using the pre-generated data stored in the `Data/` directory.
# Each figure is plotted in a **separate cell** for clarity, following the numbering used in the article (`Fig1` … `Fig2`).
#
#
# - No data generation is performed in this notebook — we only **load and visualize** the existing `.csv` files.
# - Each plotting cell is self-contained and can be executed independently.
# - Figures are saved in the `Figures/` directory and can be regenerated if needed.

# %%
# figs.generate_figure1_csv(out_csv="Data/Figure1.csv", save = True)
figs.plot_figure1_from_csv(csv_path="Data/Figure1.csv", out_fig="Figures/Fig1.pdf",save =True)

# %%
# figs.generate_figure2_csv(out_csv="Data/Figure2.csv", save = True)
figs.plot_figure2_from_csv(csv_path="Data/Figure2.csv", out_fig="Figures/Fig2.pdf",save =True)

# %%
# figs.generate_figure3_csv(out_csv="Data/Figure3.csv", save = True)
figs.plot_figure3_from_csv(csv_path="Data/Figure3.csv", out_fig="Figures/Fig3.pdf",save =True)
